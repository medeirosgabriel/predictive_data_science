# %% [markdown]
# # **Dados**
#
# Nesta tarefa, nosso objetivo é construir um modelo preditivo capaz de determinar se um paciente infectado com a COVID-19 tem risco de ir para UTI . A tarefa em questão é de classificação, tendo como atributo-alvo ICU. Os dados para esta tarefa são reais e foram coletados no hospital Sírio-Libanês. Para cada paciente presente na base de dados foram extraídas as seguintes características:  Kaggle_Sirio_Libanes_ICU_Prediction.csv
#
# Download Kaggle_Sirio_Libanes_ICU_Prediction.csv
#
#     RESPIRATORY_RATE_MAX: Frequência Respiratória Máxima que o Paciente atingiu.
#     RESPIRATORY_RATE_MEAN: Frequência Respiratória Média do Paciente.
#     AGE_PERCENTIL: Idade percentual
#     OTHER:
#     BLOODPRESSURE_SISTOLIC_MAX: Pressão sistólica máxima
#     WINDOW: Janela de admissão do paciente em horas 0-12+
#     BLOODPRESSURE_DIASTOLIC_MIN: Mínimo da Pressão diastólica
#     HTN: Pressão alta
#     RESPIRATORY_RATE_MEDIAN:  Frequência Respiratória Mediana do Paciente.
#     BLOODPRESSURE_DIASTOLIC_MEAN: Média da Pressão diastólica
#     BLOODPRESSURE_SISTOLIC_MEAN: Pressão sistólica média
#     RESPIRATORY_RATE_MIN:  Frequência Respiratória Minima  do Paciente
#     BLOODPRESSURE_DIASTOLIC_MAX: Máxima da Pressão diastólica
#     GENDER: Gênero
#     BLOODPRESSURE_SISTOLIC_MEDIAN: Pressão sistólica Mediana
#     HEART_RATE_DIFF_REL: Relação de diferença da Frequência cardíaca.
#     TEMPERATURE_MEAN: Temperatura média
#     IMMUNOCOMPROMISED: Se é IMUNOCOMPROMETIDO
#     OXYGEN_SATURATION_MAX: Saturação máxima do oxigênio.
#     ICU: Se o paciente precisou ou não da  UTI (0 e 1).
#
# Observação: Todos os valores foram normalizados entre -1 e 1.
# Descrição da atividade
#
# Para resolver o problema em questão, considere as atividades a seguir:
#
# (25%) Realize uma análise exploratória dos dados, identificando e descrevendo:
# - correlações entre as variáveis preditoras;
# - valores ausentes.
# - Inclua comentários no seu notebook em Markdown para apresentar os resultados observados;
#
# (50%) Divida os dados de treino usando a técnica holdout (80/20) em treino e validação, para  o cálculo das métricas. Baseando-se na análise feita anteriormente, utilizando todos os atributos disponíveis, treine e faça fine-tuning os seguintes modelos conforme uma validação cruzada k-folds:
# - Um modelo de Regressão Logística;
# - Um modelo de Naive Bayes;
# - Um modelo de Árvore de Decisão;
# - Um outro modelo à sua escolha, dentre os disponíveis na API do Scikit-Learn;
#
# (25%) Identifique os valores de Precision, Recall, Acurácia e F1-Score no conjunto de validação para os modelos utilizados. Existe diferença entre o desempenho no treino e na validação? Descreva o entendimento e justifique os resultados obtidos.
#
# Como devo entregar
#
#     Link para o Colab compartilhado com os professores, com as questões indexadas no próprio colab para facilitar correção.

# %% [markdown]
# # **Imports**

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from numpy import mean, std

# %% [markdown]
# # **Load Data**

# %%
df = pd.read_csv("Kaggle_Sirio_Libanes_ICU_Prediction.csv")
df.head(5)
# Out:
#    RESPIRATORY_RATE_MAX  RESPIRATORY_RATE_MEAN  WINDOW  AGE_PERCENTIL  OTHER  \
# 0             -0.575758              -0.525424       6             10    1.0
# 1              0.212121               0.355932       4             80    1.0
# 2             -0.515152              -0.549005      12             10    1.0
# 3             -0.454545              -0.389831       4             10    0.0
# 4                   NaN                    NaN       4             70    1.0
#
#    BLOODPRESSURE_SISTOLIC_MAX  BLOODPRESSURE_DIASTOLIC_MIN  HTN  \
# 0                   -0.740541                    -0.051546  0.0
# 1                   -0.329730                     0.175258  1.0
# 2                   -0.567568                    -0.175258  0.0
# 3                   -0.524324                     0.072165  0.0
# 4                   -0.610811                    -0.010309  0.0
#
#    RESPIRATORY_RATE_MEDIAN  BLOODPRESSURE_DIASTOLIC_MEAN  ...  \
# 0                -0.517241                     -0.259259  ...
# 1                 0.379310                      0.012346  ...
# 2                -0.517241                     -0.131508  ...
# 3                -0.379310                     -0.111111  ...
# 4                      NaN                     -0.209877  ...
#
#    RESPIRATORY_RATE_MIN  BLOODPRESSURE_DIASTOLIC_MAX  GENDER  \
# 0             -0.428571                    -0.487179       0
# 1              0.500000                    -0.299145       0
# 2             -0.500000                    -0.247863       0
# 3             -0.285714                    -0.384615       0
# 4                   NaN                    -0.452991       1
#
#    BLOODPRESSURE_SISTOLIC_MEDIAN  HEART_RATE_DIFF_REL  \
# 0                      -0.630769            -1.000000
# 1                      -0.046154            -1.000000
# 2                      -0.538462            -0.708718
# 3                      -0.323077            -1.000000
# 4                      -0.446154            -1.000000
#
#    BLOODPRESSURE_DIASTOLIC_MEAN.1  TEMPERATURE_MEAN  IMMUNOCOMPROMISED  \
# 0                       -0.259259          0.285714                0.0
# 1                        0.012346         -0.464286                0.0
# 2                       -0.131508         -0.201863                0.0
# 3                       -0.111111          0.107143                0.0
# 4                       -0.209877          0.178571                1.0
#
#    OXYGEN_SATURATION_MAX  ICU
# 0               0.631579    0
# 1               0.842105    0
# 2               0.842105    0
# 3               0.578947    1
# 4               0.894737    0
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['RESPIRATORY_RATE_MAX', 'RESPIRATORY_RATE_MEAN', 'WINDOW',
#        'AGE_PERCENTIL', 'OTHER', 'BLOODPRESSURE_SISTOLIC_MAX',
#        'BLOODPRESSURE_DIASTOLIC_MIN', 'HTN', 'RESPIRATORY_RATE_MEDIAN',
#        'BLOODPRESSURE_DIASTOLIC_MEAN', 'BLOODPRESSURE_SISTOLIC_MEAN',
#        'RESPIRATORY_RATE_MIN', 'BLOODPRESSURE_DIASTOLIC_MAX', 'GENDER',
#        'BLOODPRESSURE_SISTOLIC_MEDIAN', 'HEART_RATE_DIFF_REL',
#        'BLOODPRESSURE_DIASTOLIC_MEAN.1', 'TEMPERATURE_MEAN',
#        'IMMUNOCOMPROMISED', 'OXYGEN_SATURATION_MAX', 'ICU'],
#       dtype='object')

# %%
df.shape
# Out:
# (1732, 21)

# %% [markdown]
# # **Removing NaN values**

# %%
df.isnull().sum()
# Out:
# RESPIRATORY_RATE_MAX              672
# RESPIRATORY_RATE_MEAN             672
# WINDOW                              0
# AGE_PERCENTIL                       0
# OTHER                               4
# BLOODPRESSURE_SISTOLIC_MAX        616
# BLOODPRESSURE_DIASTOLIC_MIN       616
# HTN                                 4
# RESPIRATORY_RATE_MEDIAN           672
# BLOODPRESSURE_DIASTOLIC_MEAN      616
# BLOODPRESSURE_SISTOLIC_MEAN       616
# RESPIRATORY_RATE_MIN              672
# BLOODPRESSURE_DIASTOLIC_MAX       616
# GENDER                              0
# BLOODPRESSURE_SISTOLIC_MEDIAN     616
# HEART_RATE_DIFF_REL               616
# BLOODPRESSURE_DIASTOLIC_MEAN.1    616
# TEMPERATURE_MEAN                  622
# IMMUNOCOMPROMISED                   4
# OXYGEN_SATURATION_MAX             617
# ICU                                 0
# dtype: int64

# %%
df = df.dropna()
df.shape
# Out:
# (1018, 21)

# %% [markdown]
# # **Correlation**

# %%
df.corr()
# Out:
#                                 RESPIRATORY_RATE_MAX  RESPIRATORY_RATE_MEAN  \
# RESPIRATORY_RATE_MAX                        1.000000               0.627593
# RESPIRATORY_RATE_MEAN                       0.627593               1.000000
# WINDOW                                      0.495399              -0.030517
# AGE_PERCENTIL                               0.193001               0.187851
# OTHER                                       0.143118              -0.029002
# BLOODPRESSURE_SISTOLIC_MAX                  0.564956               0.180171
# BLOODPRESSURE_DIASTOLIC_MIN                -0.530938              -0.117295
# HTN                                         0.150551               0.081413
# RESPIRATORY_RATE_MEDIAN                     0.547697               0.977732
# BLOODPRESSURE_DIASTOLIC_MEAN               -0.152842              -0.102032
# BLOODPRESSURE_SISTOLIC_MEAN                 0.109606               0.156570
# RESPIRATORY_RATE_MIN                       -0.143868               0.621965
# BLOODPRESSURE_DIASTOLIC_MAX                 0.434001              -0.000896
# GENDER                                     -0.041032              -0.084924
# BLOODPRESSURE_SISTOLIC_MEDIAN               0.091080               0.157595
# HEART_RATE_DIFF_REL                         0.640121               0.064490
# BLOODPRESSURE_DIASTOLIC_MEAN.1             -0.152842              -0.102032
# TEMPERATURE_MEAN                           -0.027200               0.099596
# IMMUNOCOMPROMISED                           0.065045               0.028768
# OXYGEN_SATURATION_MAX                       0.328371              -0.106418
# ICU                                         0.590500               0.434151
#
#                                   WINDOW  AGE_PERCENTIL     OTHER  \
# RESPIRATORY_RATE_MAX            0.495399       0.193001  0.143118
# RESPIRATORY_RATE_MEAN          -0.030517       0.187851 -0.029002
# WINDOW                          1.000000       0.005283  0.245584
# AGE_PERCENTIL                   0.005283       1.000000  0.112707
# OTHER                           0.245584       0.112707  1.000000
# BLOODPRESSURE_SISTOLIC_MAX      0.476621       0.323188  0.156719
# BLOODPRESSURE_DIASTOLIC_MIN    -0.533841      -0.171422 -0.187961
# HTN                             0.085857       0.337616  0.251233
# RESPIRATORY_RATE_MEDIAN        -0.071032       0.176854 -0.047944
# BLOODPRESSURE_DIASTOLIC_MEAN   -0.043234      -0.181769 -0.043475
# BLOODPRESSURE_SISTOLIC_MEAN    -0.052141       0.311936  0.001069
# RESPIRATORY_RATE_MIN           -0.564892       0.055382 -0.176470
# BLOODPRESSURE_DIASTOLIC_MAX     0.544294       0.002046  0.155787
# GENDER                          0.027075       0.060242  0.056695
# BLOODPRESSURE_SISTOLIC_MEDIAN  -0.078094       0.303653 -0.014125
# HEART_RATE_DIFF_REL             0.771130       0.057618  0.246006
# BLOODPRESSURE_DIASTOLIC_MEAN.1 -0.043234      -0.181769 -0.043475
# TEMPERATURE_MEAN               -0.173891      -0.100578 -0.027342
# IMMUNOCOMPROMISED               0.013863       0.201481  0.185188
# OXYGEN_SATURATION_MAX           0.493645      -0.020210  0.145904
# ICU                             0.205630       0.287317 -0.032395
#
#                                 BLOODPRESSURE_SISTOLIC_MAX  \
# RESPIRATORY_RATE_MAX                              0.564956
# RESPIRATORY_RATE_MEAN                             0.180171
# WINDOW                                            0.476621
# AGE_PERCENTIL                                     0.323188
# OTHER                                             0.156719
# BLOODPRESSURE_SISTOLIC_MAX                        1.000000
# BLOODPRESSURE_DIASTOLIC_MIN                      -0.246654
# HTN                                               0.262910
# RESPIRATORY_RATE_MEDIAN                           0.142931
# BLOODPRESSURE_DIASTOLIC_MEAN                      0.234236
# BLOODPRESSURE_SISTOLIC_MEAN                       0.705464
# RESPIRATORY_RATE_MIN                             -0.331135
# BLOODPRESSURE_DIASTOLIC_MAX                       0.698593
# GENDER                                           -0.053611
# BLOODPRESSURE_SISTOLIC_MEDIAN                     0.668709
# HEART_RATE_DIFF_REL                               0.586830
# BLOODPRESSURE_DIASTOLIC_MEAN.1                    0.234236
# TEMPERATURE_MEAN                                 -0.089181
# IMMUNOCOMPROMISED                                 0.053137
# OXYGEN_SATURATION_MAX                             0.379904
# ICU                                               0.384455
#
#                                 BLOODPRESSURE_DIASTOLIC_MIN       HTN  \
# RESPIRATORY_RATE_MAX                              -0.530938  0.150551
# RESPIRATORY_RATE_MEAN                             -0.117295  0.081413
# WINDOW                                            -0.533841  0.085857
# AGE_PERCENTIL                                     -0.171422  0.337616
# OTHER                                             -0.187961  0.251233
# BLOODPRESSURE_SISTOLIC_MAX                        -0.246654  0.262910
# BLOODPRESSURE_DIASTOLIC_MIN                        1.000000 -0.131907
# HTN                                               -0.131907  1.000000
# RESPIRATORY_RATE_MEDIAN                           -0.073732  0.066769
# BLOODPRESSURE_DIASTOLIC_MEAN                       0.752693 -0.039058
# BLOODPRESSURE_SISTOLIC_MEAN                        0.321021  0.199021
# RESPIRATORY_RATE_MIN                               0.388867 -0.035815
# BLOODPRESSURE_DIASTOLIC_MAX                       -0.053319  0.101237
# GENDER                                            -0.105177 -0.031123
# BLOODPRESSURE_SISTOLIC_MEDIAN                      0.338433  0.190311
# HEART_RATE_DIFF_REL                               -0.608016  0.130766
# BLOODPRESSURE_DIASTOLIC_MEAN.1                     0.752693 -0.039058
# TEMPERATURE_MEAN                                   0.094495 -0.097012
# IMMUNOCOMPROMISED                                 -0.108978  0.172969
# OXYGEN_SATURATION_MAX                             -0.432992  0.115209
# ICU                                               -0.412389  0.185915
#
#                                 RESPIRATORY_RATE_MEDIAN  \
# RESPIRATORY_RATE_MAX                           0.547697
# RESPIRATORY_RATE_MEAN                          0.977732
# WINDOW                                        -0.071032
# AGE_PERCENTIL                                  0.176854
# OTHER                                         -0.047944
# BLOODPRESSURE_SISTOLIC_MAX                     0.142931
# BLOODPRESSURE_DIASTOLIC_MIN                   -0.073732
# HTN                                            0.066769
# RESPIRATORY_RATE_MEDIAN                        1.000000
# BLOODPRESSURE_DIASTOLIC_MEAN                  -0.089194
# BLOODPRESSURE_SISTOLIC_MEAN                    0.157650
# RESPIRATORY_RATE_MIN                           0.639634
# BLOODPRESSURE_DIASTOLIC_MAX                   -0.032570
# GENDER                                        -0.088127
# BLOODPRESSURE_SISTOLIC_MEDIAN                  0.158203
# HEART_RATE_DIFF_REL                            0.012608
# BLOODPRESSURE_DIASTOLIC_MEAN.1                -0.089194
# TEMPERATURE_MEAN                               0.117536
# IMMUNOCOMPROMISED                              0.022432
# OXYGEN_SATURATION_MAX                         -0.130574
# ICU                                            0.389363
#
#                                 BLOODPRESSURE_DIASTOLIC_MEAN  ...  \
# RESPIRATORY_RATE_MAX                               -0.152842  ...
# RESPIRATORY_RATE_MEAN                              -0.102032  ...
# WINDOW                                             -0.043234  ...
# AGE_PERCENTIL                                      -0.181769  ...
# OTHER                                              -0.043475  ...
# BLOODPRESSURE_SISTOLIC_MAX                          0.234236  ...
# BLOODPRESSURE_DIASTOLIC_MIN                         0.752693  ...
# HTN                                                -0.039058  ...
# RESPIRATORY_RATE_MEDIAN                            -0.089194  ...
# BLOODPRESSURE_DIASTOLIC_MEAN                        1.000000  ...
# BLOODPRESSURE_SISTOLIC_MEAN                         0.476301  ...
# RESPIRATORY_RATE_MIN                                0.020245  ...
# BLOODPRESSURE_DIASTOLIC_MAX                         0.538050  ...
# GENDER                                             -0.127759  ...
# BLOODPRESSURE_SISTOLIC_MEDIAN                       0.474012  ...
# HEART_RATE_DIFF_REL                                -0.085504  ...
# BLOODPRESSURE_DIASTOLIC_MEAN.1                      1.000000  ...
# TEMPERATURE_MEAN                                   -0.008409  ...
# IMMUNOCOMPROMISED                                  -0.125234  ...
# OXYGEN_SATURATION_MAX                              -0.092622  ...
# ICU                                                -0.261935  ...
#
#                                 RESPIRATORY_RATE_MIN  \
# RESPIRATORY_RATE_MAX                       -0.143868
# RESPIRATORY_RATE_MEAN                       0.621965
# WINDOW                                     -0.564892
# AGE_PERCENTIL                               0.055382
# OTHER                                      -0.176470
# BLOODPRESSURE_SISTOLIC_MAX                 -0.331135
# BLOODPRESSURE_DIASTOLIC_MIN                 0.388867
# HTN                                        -0.035815
# RESPIRATORY_RATE_MEDIAN                     0.639634
# BLOODPRESSURE_DIASTOLIC_MEAN                0.020245
# BLOODPRESSURE_SISTOLIC_MEAN                 0.099409
# RESPIRATORY_RATE_MIN                        1.000000
# BLOODPRESSURE_DIASTOLIC_MAX                -0.436170
# GENDER                                     -0.051207
# BLOODPRESSURE_SISTOLIC_MEDIAN               0.119874
# HEART_RATE_DIFF_REL                        -0.588996
# BLOODPRESSURE_DIASTOLIC_MEAN.1              0.020245
# TEMPERATURE_MEAN                            0.147812
# IMMUNOCOMPROMISED                          -0.015226
# OXYGEN_SATURATION_MAX                      -0.481277
# ICU                                        -0.035250
#
#                                 BLOODPRESSURE_DIASTOLIC_MAX    GENDER  \
# RESPIRATORY_RATE_MAX                               0.434001 -0.041032
# RESPIRATORY_RATE_MEAN                             -0.000896 -0.084924
# WINDOW                                             0.544294  0.027075
# AGE_PERCENTIL                                      0.002046  0.060242
# OTHER                                              0.155787  0.056695
# BLOODPRESSURE_SISTOLIC_MAX                         0.698593 -0.053611
# BLOODPRESSURE_DIASTOLIC_MIN                       -0.053319 -0.105177
# HTN                                                0.101237 -0.031123
# RESPIRATORY_RATE_MEDIAN                           -0.032570 -0.088127
# BLOODPRESSURE_DIASTOLIC_MEAN                       0.538050 -0.127759
# BLOODPRESSURE_SISTOLIC_MEAN                        0.340210 -0.118054
# RESPIRATORY_RATE_MIN                              -0.436170 -0.051207
# BLOODPRESSURE_DIASTOLIC_MAX                        1.000000 -0.044014
# GENDER                                            -0.044014  1.000000
# BLOODPRESSURE_SISTOLIC_MEDIAN                      0.310126 -0.120923
# HEART_RATE_DIFF_REL                                0.643721 -0.017413
# BLOODPRESSURE_DIASTOLIC_MEAN.1                     0.538050 -0.127759
# TEMPERATURE_MEAN                                  -0.110612 -0.119335
# IMMUNOCOMPROMISED                                 -0.035356 -0.002943
# OXYGEN_SATURATION_MAX                              0.380935  0.129700
# ICU                                                0.117611 -0.064489
#
#                                 BLOODPRESSURE_SISTOLIC_MEDIAN  \
# RESPIRATORY_RATE_MAX                                 0.091080
# RESPIRATORY_RATE_MEAN                                0.157595
# WINDOW                                              -0.078094
# AGE_PERCENTIL                                        0.303653
# OTHER                                               -0.014125
# BLOODPRESSURE_SISTOLIC_MAX                           0.668709
# BLOODPRESSURE_DIASTOLIC_MIN                          0.338433
# HTN                                                  0.190311
# RESPIRATORY_RATE_MEDIAN                              0.158203
# BLOODPRESSURE_DIASTOLIC_MEAN                         0.474012
# BLOODPRESSURE_SISTOLIC_MEAN                          0.989754
# RESPIRATORY_RATE_MIN                                 0.119874
# BLOODPRESSURE_DIASTOLIC_MAX                          0.310126
# GENDER                                              -0.120923
# BLOODPRESSURE_SISTOLIC_MEDIAN                        1.000000
# HEART_RATE_DIFF_REL                                 -0.020694
# BLOODPRESSURE_DIASTOLIC_MEAN.1                       0.474012
# TEMPERATURE_MEAN                                     0.023566
# IMMUNOCOMPROMISED                                    0.017818
# OXYGEN_SATURATION_MAX                               -0.018405
# ICU                                                  0.157520
#
#                                 HEART_RATE_DIFF_REL  \
# RESPIRATORY_RATE_MAX                       0.640121
# RESPIRATORY_RATE_MEAN                      0.064490
# WINDOW                                     0.771130
# AGE_PERCENTIL                              0.057618
# OTHER                                      0.246006
# BLOODPRESSURE_SISTOLIC_MAX                 0.586830
# BLOODPRESSURE_DIASTOLIC_MIN               -0.608016
# HTN                                        0.130766
# RESPIRATORY_RATE_MEDIAN                    0.012608
# BLOODPRESSURE_DIASTOLIC_MEAN              -0.085504
# BLOODPRESSURE_SISTOLIC_MEAN                0.003269
# RESPIRATORY_RATE_MIN                      -0.588996
# BLOODPRESSURE_DIASTOLIC_MAX                0.643721
# GENDER                                    -0.017413
# BLOODPRESSURE_SISTOLIC_MEDIAN             -0.020694
# HEART_RATE_DIFF_REL                        1.000000
# BLOODPRESSURE_DIASTOLIC_MEAN.1            -0.085504
# TEMPERATURE_MEAN                          -0.139248
# IMMUNOCOMPROMISED                          0.030285
# OXYGEN_SATURATION_MAX                      0.535545
# ICU                                        0.315657
#
#                                 BLOODPRESSURE_DIASTOLIC_MEAN.1  \
# RESPIRATORY_RATE_MAX                                 -0.152842
# RESPIRATORY_RATE_MEAN                                -0.102032
# WINDOW                                               -0.043234
# AGE_PERCENTIL                                        -0.181769
# OTHER                                                -0.043475
# BLOODPRESSURE_SISTOLIC_MAX                            0.234236
# BLOODPRESSURE_DIASTOLIC_MIN                           0.752693
# HTN                                                  -0.039058
# RESPIRATORY_RATE_MEDIAN                              -0.089194
# BLOODPRESSURE_DIASTOLIC_MEAN                          1.000000
# BLOODPRESSURE_SISTOLIC_MEAN                           0.476301
# RESPIRATORY_RATE_MIN                                  0.020245
# BLOODPRESSURE_DIASTOLIC_MAX                           0.538050
# GENDER                                               -0.127759
# BLOODPRESSURE_SISTOLIC_MEDIAN                         0.474012
# HEART_RATE_DIFF_REL                                  -0.085504
# BLOODPRESSURE_DIASTOLIC_MEAN.1                        1.000000
# TEMPERATURE_MEAN                                     -0.008409
# IMMUNOCOMPROMISED                                    -0.125234
# OXYGEN_SATURATION_MAX                                -0.092622
# ICU                                                  -0.261935
#
#                                 TEMPERATURE_MEAN  IMMUNOCOMPROMISED  \
# RESPIRATORY_RATE_MAX                   -0.027200           0.065045
# RESPIRATORY_RATE_MEAN                   0.099596           0.028768
# WINDOW                                 -0.173891           0.013863
# AGE_PERCENTIL                          -0.100578           0.201481
# OTHER                                  -0.027342           0.185188
# BLOODPRESSURE_SISTOLIC_MAX             -0.089181           0.053137
# BLOODPRESSURE_DIASTOLIC_MIN             0.094495          -0.108978
# HTN                                    -0.097012           0.172969
# RESPIRATORY_RATE_MEDIAN                 0.117536           0.022432
# BLOODPRESSURE_DIASTOLIC_MEAN           -0.008409          -0.125234
# BLOODPRESSURE_SISTOLIC_MEAN             0.008406           0.020434
# RESPIRATORY_RATE_MIN                    0.147812          -0.015226
# BLOODPRESSURE_DIASTOLIC_MAX            -0.110612          -0.035356
# GENDER                                 -0.119335          -0.002943
# BLOODPRESSURE_SISTOLIC_MEDIAN           0.023566           0.017818
# HEART_RATE_DIFF_REL                    -0.139248           0.030285
# BLOODPRESSURE_DIASTOLIC_MEAN.1         -0.008409          -0.125234
# TEMPERATURE_MEAN                        1.000000           0.006473
# IMMUNOCOMPROMISED                       0.006473           1.000000
# OXYGEN_SATURATION_MAX                  -0.235308           0.018816
# ICU                                    -0.096691           0.047306
#
#                                 OXYGEN_SATURATION_MAX       ICU
# RESPIRATORY_RATE_MAX                         0.328371  0.590500
# RESPIRATORY_RATE_MEAN                       -0.106418  0.434151
# WINDOW                                       0.493645  0.205630
# AGE_PERCENTIL                               -0.020210  0.287317
# OTHER                                        0.145904 -0.032395
# BLOODPRESSURE_SISTOLIC_MAX                   0.379904  0.384455
# BLOODPRESSURE_DIASTOLIC_MIN                 -0.432992 -0.412389
# HTN                                          0.115209  0.185915
# RESPIRATORY_RATE_MEDIAN                     -0.130574  0.389363
# BLOODPRESSURE_DIASTOLIC_MEAN                -0.092622 -0.261935
# BLOODPRESSURE_SISTOLIC_MEAN                  0.000720  0.168378
# RESPIRATORY_RATE_MIN                        -0.481277 -0.035250
# BLOODPRESSURE_DIASTOLIC_MAX                  0.380935  0.117611
# GENDER                                       0.129700 -0.064489
# BLOODPRESSURE_SISTOLIC_MEDIAN               -0.018405  0.157520
# HEART_RATE_DIFF_REL                          0.535545  0.315657
# BLOODPRESSURE_DIASTOLIC_MEAN.1              -0.092622 -0.261935
# TEMPERATURE_MEAN                            -0.235308 -0.096691
# IMMUNOCOMPROMISED                            0.018816  0.047306
# OXYGEN_SATURATION_MAX                        1.000000  0.242648
# ICU                                          0.242648  1.000000
#
# [21 rows x 21 columns]

# %%
corr = dict(df.corr())
results = [(k, v['ICU']) for k, v in corr.items()]
results.sort(key=lambda x: x[1], reverse=True)
results[0:3]
# Out:
# [('ICU', 1.0),
#  ('RESPIRATORY_RATE_MAX', 0.5905004548441919),
#  ('RESPIRATORY_RATE_MEAN', 0.43415135081217776)]

# %% [markdown]
# ## **Removing NaN values**
# - #### **RESPIRATORY_RATE_MAX** - 0.590
# - #### **RESPIRATORY_RATE_MEAN** - 0.434
# - #### **RESPIRATORY_RATE_MEDIAN** - 0.389

# %% [markdown]
# # **Split Train and Test**
# - #### **TRAIN** - 0.8
# - #### **TEST** - 0.2

# %%
X_columns = list(df.columns)
X_columns.remove('ICU')
y_column = ['ICU']
X = df[X_columns]
y = df[y_column]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # **Training Models**
# - #### **Default Configuration**

# %% [markdown]
# # **Logistic Regression**

# %%
model = LogisticRegression()
kfold = KFold(n_splits=5, shuffle=True)
scores = cross_val_score(model, X_train, y_train, cv = kfold)

# %%
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.839 (0.039)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
target_names = ['NO UTI', 'UTI'] 
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       NO UTI       0.80      0.93      0.86       116
#          UTI       0.88      0.69      0.78        88
#
#     accuracy                           0.83       204
#    macro avg       0.84      0.81      0.82       204
# weighted avg       0.84      0.83      0.82       204
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # **Naive Bayes**

# %%
model = GaussianNB()
kfold = KFold(n_splits=5, shuffle=True)
scores = cross_val_score(model, X_train, y_train, cv = kfold)

# %%
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.830 (0.027)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
target_names = ['NO UTI', 'UTI'] 
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       NO UTI       0.78      0.93      0.85       116
#          UTI       0.88      0.65      0.75        88
#
#     accuracy                           0.81       204
#    macro avg       0.83      0.79      0.80       204
# weighted avg       0.82      0.81      0.80       204
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # **Decision Tree**

# %%
model = DecisionTreeClassifier()
kfold = KFold(n_splits=5, shuffle=True)
scores = cross_val_score(model, X_train, y_train, cv = kfold)

# %%
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.784 (0.021)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
target_names = ['NO UTI', 'UTI'] 
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       NO UTI       0.77      0.87      0.82       116
#          UTI       0.79      0.66      0.72        88
#
#     accuracy                           0.78       204
#    macro avg       0.78      0.76      0.77       204
# weighted avg       0.78      0.78      0.78       204

# %% [markdown]
# # **SVM**

# %%
model = SVC(kernel='linear')
kfold = KFold(n_splits=5, shuffle=True)
scores = cross_val_score(model, X_train, y_train, cv = kfold)

# %%
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.838 (0.017)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
target_names = ['NO UTI', 'UTI'] 
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       NO UTI       0.81      0.93      0.86       116
#          UTI       0.89      0.70      0.78        88
#
#     accuracy                           0.83       204
#    macro avg       0.85      0.82      0.82       204
# weighted avg       0.84      0.83      0.83       204
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # **Descrição do entendimento dos resultados obtidos.**
# #### Observando os resultados dos modelos, é visível que as métricas do conjunto de treino e do de teste possuem valores bastnate parecidos. Isso deve-se a validação validação cruzada k-folds, em que ocorre o particionamento do conjunto de dados em subconjuntos mutuamente exclusivos, e posteriormente, o uso de alguns destes subconjuntos para a estimação dos parâmetros do modelo (dados de treinamento), sendo os subconjuntos restantes (dados de validação ou de teste) empregados na validação do modelo.
