# %% [markdown]
# # Imports

# %%
import keras
from tensorflow.keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %% [markdown]
# # Split fashion_mnist data

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train.shape, x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# # Number of classes

# %%
import numpy as np

num_classes = len(np.unique(y_test))
num_classes
# Out:
# 10

# %% [markdown]
# # Pre Processing

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

# %% [markdown]
# # Neural Network - CNN

# %%
num_classes = 10

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
batch_size = 128
epochs = 25

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 469/469 [==============================] - 11s 14ms/step - loss: 0.4669 - accuracy: 0.8343 - val_loss: 0.3182 - val_accuracy: 0.8860
# Epoch 2/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3018 - accuracy: 0.8907 - val_loss: 0.2626 - val_accuracy: 0.9038
# Epoch 3/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2530 - accuracy: 0.9069 - val_loss: 0.2455 - val_accuracy: 0.9096
# Epoch 4/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2233 - accuracy: 0.9176 - val_loss: 0.2269 - val_accuracy: 0.9142
# Epoch 5/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1947 - accuracy: 0.9277 - val_loss: 0.2184 - val_accuracy: 0.9211
# Epoch 6/25
# 469/469 [==============================] - 4s 10ms/step - loss: 0.1776 - accuracy: 0.9342 - val_loss: 0.2145 - val_accuracy: 0.9233
# Epoch 7/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1586 - accuracy: 0.9413 - val_loss: 0.2124 - val_accuracy: 0.9246
# Epoch 8/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1439 - accuracy: 0.9460 - val_loss: 0.2098 - val_accuracy: 0.9269
# Epoch 9/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1323 - accuracy: 0.9507 - val_loss: 0.2035 - val_accuracy: 0.9308
# Epoch 10/25
# 469/469 [==============================] - 4s 10ms/step - loss: 0.1203 - accuracy: 0.9546 - val_loss: 0.2049 - val_accuracy: 0.9288
# Epoch 11/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1103 - accuracy: 0.9590 - val_loss: 0.2185 - val_accuracy: 0.9298
# Epoch 12/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0996 - accuracy: 0.9628 - val_loss: 0.2202 - val_accuracy: 0.9286
# Epoch 13/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0923 - accuracy: 0.9653 - val_loss: 0.2218 - val_accuracy: 0.9303
# Epoch 14/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0857 - accuracy: 0.9671 - val_loss: 0.2295 - val_accuracy: 0.9308
# Epoch 15/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0779 - accuracy: 0.9707 - val_loss: 0.2359 - val_accuracy: 0.9296
# Epoch 16/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0757 - accuracy: 0.9717 - val_loss: 0.2408 - val_accuracy: 0.9312
# Epoch 17/25
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0702 - accuracy: 0.9735 - val_loss: 0.2406 - val_accuracy: 0.9313
# Epoch 18/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0636 - accuracy: 0.9762 - val_loss: 0.2555 - val_accuracy: 0.9274
# Epoch 19/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0639 - accuracy: 0.9761 - val_loss: 0.2507 - val_accuracy: 0.9319
# Epoch 20/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0576 - accuracy: 0.9788 - val_loss: 0.2590 - val_accuracy: 0.9331
# Epoch 21/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0558 - accuracy: 0.9785 - val_loss: 0.2685 - val_accuracy: 0.9339
# Epoch 22/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0538 - accuracy: 0.9800 - val_loss: 0.2866 - val_accuracy: 0.9284
# Epoch 23/25
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0518 - accuracy: 0.9804 - val_loss: 0.2549 - val_accuracy: 0.9338
# Epoch 24/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0483 - accuracy: 0.9819 - val_loss: 0.2806 - val_accuracy: 0.9325
# Epoch 25/25
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0496 - accuracy: 0.9818 - val_loss: 0.2808 - val_accuracy: 0.9319

# %% [markdown]
# # Evaluation

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.28084924817085266
# Test accuracy: 0.9319000244140625

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
y_pred = list(map(lambda x: list(x).index(max(x)), model.predict(x_test)))
y_test = list(map(lambda x: list(x).index(max(x)), y_test))
print(classification_report(y_test, y_pred))
# Out:
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      1000
#            1       0.99      0.99      0.99      1000
#            2       0.88      0.91      0.90      1000
#            3       0.93      0.92      0.93      1000
#            4       0.89      0.89      0.89      1000
#            5       0.99      0.98      0.99      1000
#            6       0.83      0.78      0.80      1000
#            7       0.97      0.98      0.97      1000
#            8       0.99      0.98      0.99      1000
#            9       0.98      0.97      0.98      1000
#
#     accuracy                           0.93     10000
#    macro avg       0.93      0.93      0.93     10000
# weighted avg       0.93      0.93      0.93     10000
